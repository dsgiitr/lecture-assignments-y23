# %%
import numpy as np
from matplotlib import pyplot as plt
b=[]
for i in range(0,10000):
    a=(np.random.randint(0,2,1000)*2-1).cumsum()
    b.append(a)
b=np.array(b)
b=b.flatten()
plt.hist(b)
# Out:
# (array([1.532000e+03, 1.854900e+04, 1.656710e+05, 8.147630e+05,
#         2.944312e+06, 4.397928e+06, 1.327172e+06, 2.846320e+05,
#         4.245800e+04, 2.983000e+03]),
#  array([-120. ,  -96.8,  -73.6,  -50.4,  -27.2,   -4. ,   19.2,   42.4,
#           65.6,   88.8,  112. ]),
#  <BarContainer object of 10 artists>)
