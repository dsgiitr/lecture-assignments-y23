# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import random

# %%
for i in range (0,10):
    x=np.random.exponential(1/5,200)
    pos=0
    for i in range (0,200):
        pos+=x[i]
        x[i]=pos
    plt.plot(x)
