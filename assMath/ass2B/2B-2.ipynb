# %% [markdown]
# ### Importing Libraries and loading datasets

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error

train_A=pd.read_csv("~/Downloads/train_set_A.csv")
test_A=pd.read_csv("~/Downloads/test_set_A.csv")
train_B=pd.read_csv("~/Downloads/train_set_B.csv")
test_B=pd.read_csv("~/Downloads/test_set_B.csv")
train_C=pd.read_csv("~/Downloads/train_set_C.csv")
test_C=pd.read_csv("~/Downloads/test_set_C.csv")

# %% [markdown]
# ## SetA

# %%
#training a linear regression model on train_A dataset
A_x=train_A['x'].to_numpy().reshape(-1,1)
A_y=train_A['y'].to_numpy().reshape(-1,1)

A_x_test=test_A['x'].to_numpy().reshape(-1,1)
A_y_test=test_A['y'].to_numpy().reshape(-1,1)
reg_A=LinearRegression().fit(A_x,A_y)

A_y_pred=reg_A.predict(A_x)

# %% [markdown]
# ### Error plots in set A

# %%
error_A=(A_y_pred-A_y)
fig,ax=plt.subplots(1,2,figsize=(10,5),layout='constrained')
ax[0].set_xlabel('error')
ax[0].set_ylabel('density')
ax[0].set_title('Train set A error distribution')
ax[1].set_xlabel('error')
ax[1].set_ylabel('density')
ax[1].set_title('Test set A error distribution')

n, bins, patches = ax[0].hist(error, bins=100, facecolor='#2ab0ff', edgecolor='#e0e0e0', linewidth=0.5, alpha=1)
n = n.astype('int')
for i in range(len(patches)):
    patches[i].set_facecolor(plt.cm.viridis(n[i]/max(n)))
    
error_A_test=(reg_A.predict(A_x_test)-A_y_test)
n, bins, patches = ax[1].hist(error_A_test, bins=100, facecolor='#2ab0aa', edgecolor='#e0e0ff', linewidth=0.5, alpha=1)
n = n.astype('int')
for i in range(len(patches)):
    patches[i].set_facecolor(plt.cm.viridis(n[i]/max(n)))

# %% [markdown]
# The train set A and test set A doesnt follow the same distribution

# %% [markdown]
# ## Set B

# %%
B_x=train_B['x'].to_numpy().reshape(-1,1)
B_y=train_B['y'].to_numpy().reshape(-1,1)

B_x_test=test_B['x'].to_numpy().reshape(-1,1)
B_y_test=test_B['y'].to_numpy().reshape(-1,1)
reg_B=LinearRegression().fit(B_x,B_y)
B_y_pred=reg_B.predict(B_x)
error_B=(B_y,B_y_pred)

# %% [markdown]
# ### Error plots in Set B

# %%
error_B=(B_y_pred-B_y)
fig,ax=plt.subplots(1,2,figsize=(10,5),layout='constrained')
# ax.hist(error,bins=bins,color="c")
ax[0].set_xlabel('error')
ax[0].set_ylabel('density')
ax[0].set_title('Train set B error distribution')
ax[1].set_xlabel('error')
ax[1].set_ylabel('density')
ax[1].set_title('Test set B error distribution')

n, bins, patches = ax[0].hist(error_B, bins=100, facecolor='#2ab0ff', edgecolor='#e0e0e0', linewidth=0.5, alpha=1)
n = n.astype('int')
for i in range(len(patches)):
    patches[i].set_facecolor(plt.cm.viridis(n[i]/max(n)))
    
    
error_B_test=(reg_B.predict(B_x_test)-B_y_test)
n, bins, patches = ax[1].hist(error_B_test, bins=100, facecolor='#2ab0aa', edgecolor='#e0e0ff', linewidth=0.5, alpha=1)
n = n.astype('int')
for i in range(len(patches)):
    patches[i].set_facecolor(plt.cm.viridis(n[i]/max(n)))
    
ax[0].axvline(error_B.mean(), color='k', linestyle='dashed', linewidth=1)
ax[1].axvline(error_B_test.mean(), color='k', linestyle='dashed', linewidth=1)

# %% [markdown]
# The train set B and test set B follows same distribtion

# %% [markdown]
# ## Set C

# %%
C_x=train_C['x'].to_numpy().reshape(-1,1)
C_y=train_C['y'].to_numpy().reshape(-1,1)

C_x_test=test_C['x'].to_numpy().reshape(-1,1)
C_y_test=test_C['y'].to_numpy().reshape(-1,1)
reg_C=LinearRegression().fit(C_x,C_y)
C_y_pred=reg_C.predict(C_x)
error_C=(C_y,C_y_pred)

# %% [markdown]
# ### Error plots in Set C

# %%
error_C=(C_y_pred-C_y)
fig,ax=plt.subplots(1,2,figsize=(10,5),layout='constrained')

ax[0].set_xlabel('error')
ax[0].set_ylabel('density')
ax[0].set_title('Train set C error distribution')
ax[1].set_xlabel('error')
ax[1].set_ylabel('density')
ax[1].set_title('Test set C error distribution')
n, bins, patches = ax[0].hist(error_C, bins=100, facecolor='#2ab0ff', edgecolor='#e0e0e0', linewidth=0.5, alpha=1)
n = n.astype('int')
for i in range(len(patches)):
    patches[i].set_facecolor(plt.cm.viridis(n[i]/max(n)))
    
    
    
error_C_test=(reg_C.predict(C_x_test)-C_y_test)
n, bins, patches = ax[1].hist(error_C_test, bins=100, facecolor='#2ab0aa', edgecolor='#e0e0ff', linewidth=0.5, alpha=1)
n = n.astype('int')
for i in range(len(patches)):
    patches[i].set_facecolor(plt.cm.viridis(n[i]/max(n)))
