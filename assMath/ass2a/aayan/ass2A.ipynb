# %% [markdown]
# Question-1 :
# ![1-part1](./1-i.jpg)
# ![1-part2](./1-ii.jpg)

# %% [markdown]
# Question 2a :
# ![2a-part1](./2a-i.jpg)
# ![2a-part2](./2a-ii.jpg)
# ![2a-part3](./2a-iii.jpg)

# %% [markdown]
# Question 2b:
#
#
# ![2b](./2b.jpg)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
x=np.arange(-10,20,0.001)
plt.plot(x,norm.pdf(x,5,9))
plt.plot(x,norm.pdf(x,5.9,0.9))
plt.show()

# %% [markdown]
# Question 2c:
#
# ![2c](./2c.jpg)

# %% [markdown]
# Question 2d:
#
# ![2d-part1](./2d-i.jpg)
# ![2d-part2](./2d-ii.jpg)

# %% [markdown]
# Question 3 :
#
# Theory part:
#
# ![Theory Q3-i](./3-i.jpg)
# ![Theory Q3-ii](./3-ii.jpg)
#
# Python Implementation:

# %%
import numpy as np
s=np.random.normal(0,10,100000)#taking 100000 samples from distribution of mean 0 and standard deviation 10
m=np.mean(s)
sdev=np.std(s)
print("MLE estimate to population mean = ",m)
print("MLE estimate to population standard deviation = ",sdev)
# Out:
# MLE estimate to population mean =  0.027379021923162845
# MLE estimate to population standard deviation =  9.982042655637075
