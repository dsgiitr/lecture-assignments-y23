# %%
from tqdm import tqdm
import matplotlib.pyplot as plt
import time
import random
import cmath
import numpy as np
import math
lmb=float(input())
# Out:
# 5

# %%
for j in tqdm(range(1000)):
    position=0
    listmain={}
    for i in range(100):
        listmain[i]=position
        position+=np.random.normal(0,50)
    plt.plot(listmain.keys(),listmain.values(),c=np.random.random(3,))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 2377.94it/s]
